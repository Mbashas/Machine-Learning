# %%
import pandas as pd


data = pd.read_excel('data/idea_export_voter_turnout_database_region.xlsx')

# %%
data = pd.read_excel('data/DatabankWide.xlsx')

# %%
data = pd.read_csv('data/wgm_full_wave2_public_file_final (1)_csv.csv')
# Out:
# C:\Users\seth\AppData\Local\Temp\ipykernel_25652\1185356719.py:1: DtypeWarning: Columns (9,11,13,20,31,32,33,34,35,36,37,39,40,41,42,43,44,45,47,71,72,73,74,75,76,84,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/wgm_full_wave2_public_file_final (1)_csv.csv')

# %%
data = pd.read_csv('data/diabetes_012_health_indicators_BRFSS2015.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          253680 non-null  float64
#  1   HighBP                253680 non-null  float64
#  2   HighChol              253680 non-null  float64
#  3   CholCheck             253680 non-null  float64
#  4   BMI                   253680 non-null  float64
#  5   Smoker                253680 non-null  float64
#  6   Stroke                253680 non-null  float64
#  7   HeartDiseaseorAttack  253680 non-null  float64
#  8   PhysActivity          253680 non-null  float64
#  9   Fruits                253680 non-null  float64
#  10  Veggies               253680 non-null  float64
#  11  HvyAlcoholConsump     253680 non-null  float64
#  12  AnyHealthcare         253680 non-null  float64
#  13  NoDocbcCost           253680 non-null  float64
# ...

# %%
data.shape
# Out:
# (253680, 22)

# %%
data
# Out:
#            COUNTRYNEW  WPID_RANDOM       WGT         PROJWT  FIELD_DATE  \
# 0       United States    178216898  0.803440  211560.297000  10/01/2020
# 1       United States    159107018  0.729590  192114.267400  10/01/2020
# 2       United States    203166417  0.848559  223440.987100  10/01/2020
# 3       United States    201061719  0.341083   89813.417720  10/01/2020
# 4       United States    195404162  0.995933  262247.166300  10/01/2020
# ...               ...          ...       ...            ...         ...
# 119083         Kosovo    201030063  0.250480     312.414031  12/01/2020
# 119084         Kosovo    117528235  0.188637     235.279337  12/01/2020
# 119085         Kosovo    152050010  0.191664     239.054757  12/01/2020
# 119086         Kosovo    111183978  0.173042     215.827630  12/01/2020
# 119087         Kosovo    186948831  0.131784     164.369055  12/01/2020
#
#         YEAR_WAVE  W1  W2 W3 W4  ...  age_var1 age_var2  age_var3 Gender  \
# ...

# %%
data.isna().sum()
# Out:
# COUNTRYNEW           0
# WPID_RANDOM          0
# WGT                  0
# PROJWT               0
# FIELD_DATE           0
#                     ..
# Household_Income     0
# Global11Regions      0
# wbi                  0
# Subjective_Income    0
# EMP_2010             0
# Length: 89, dtype: int64

# %%
data
# Out:
#                                    Country name Country code  Year  \
# 0                                   Afghanistan          AFG  2011
# 1                                   Afghanistan          AFG  2014
# 2                                   Afghanistan          AFG  2017
# 3                                   Afghanistan          AFG  2021
# 4                                       Albania          ALB  2011
# ..                                          ...          ...   ...
# 653  Sub-Saharan Africa (excluding high income)          SSA  2021
# 654                                       World          WLD  2011
# 655                                       World          WLD  2014
# 656                                       World          WLD  2017
# 657                                       World          WLD  2021
#
#      Adult populaiton                                         Region  \
# 0        1.512447e+07                                     South Asia
# ...

# %%
data = pd.read_csv('data/3i-survey-data-2022.csv', encoding='latin1')

# %%
data = pd.read_csv('data/sosc_2022_10_19_codebook_aggregate.csv')

# %%
data = pd.read_csv('data/countries-countries-fb-social-connectedness-index-october-2021.tsv', sep='\t')

# %%
data.shape
# Out:
# (85, 4)

# %%
data
# Out:
#                     variable  \
# 0          general_connected
# 1          general_supported
# 2             general_lonely
# 3     loneliness_scale_neg_1
# 4     loneliness_scale_neg_2
# ..                       ...
# 80           internet_access
# 81          internet_used_7d
# 82     mobile_phone_internet
# 83  loneliness_neg_composite
# 84         support_composite
#
#                                         question_text  \
# 0   In general, how connected do you feel to peopl...
# 1   In general, how supported do you feel by peopl...
# 2   In general, how lonely do you feel? By lonely,...
# 3   How often do you feel that you lack companions...
# 4                     How often do you feel left out?
# ..                                                ...
# 80  Do you have access to the Internet in any way,...
# 81  Have you used the Internet in the past seven d...
# 82  Can your mobile phone be used to access the In...
# 83                                                NaN
# ...

# %%
data.isnull().sum()
# Out:
# country                          0
# variable                         0
# value                           14
# estimate_weighted                0
# estimate_weighted_se             0
# estimate_weighted_95ci_low       0
# estimate_weighted_95ci_upp       0
# n_unweighted                     0
# question_text                   28
# notes                         1938
# dtype: int64

# %%
data.columns.tolist()
# Out:
# ['country',
#  'variable',
#  'value',
#  'estimate_weighted',
#  'estimate_weighted_se',
#  'estimate_weighted_95ci_low',
#  'estimate_weighted_95ci_upp',
#  'n_unweighted',
#  'question_text',
#  'notes']

# %%
data.head()
# Out:
#   country           variable                 value  estimate_weighted  \
# 0      BR  general_connected  Not at all connected           0.064963
# 1      BR  general_connected    A little connected           0.397393
# 2      BR  general_connected      Fairly connected           0.297877
# 3      BR  general_connected        Very connected           0.234647
# 4      BR  general_connected                 DK/NR           0.005120
#
#    estimate_weighted_se  estimate_weighted_95ci_low  \
# 0              0.006610                    0.053145
# 1              0.013689                    0.370889
# 2              0.011783                    0.275304
# 3              0.011834                    0.212246
# 4              0.001230                    0.003196
#
#    estimate_weighted_95ci_upp  n_unweighted  \
# 0                    0.079189           134
# 1                    0.424512           785
# 2                    0.321481           581
# 3                    0.258637           483
# ...

# %%
data.question_text.unique()
# Out:
# array(['In general, how connected do you feel to people? By connected, I mean how close you feel to people emotionally. Do you feel...?',
#        'In general, how supported do you feel by people? By supported, I mean how much you feel cared for by people. Do you feel...?',
#        'In general, how lonely do you feel? By lonely, I mean how much you feel emotionally isolated from people. Do you feel...?',
#        'How often do you feel that you lack companionship?',
#        'How often do you feel left out?',
#        'How often do you feel isolated from others?',
#        'How often do you feel that there are people who really understand you?',
#        'How often do you feel that there are people you can talk to?',
#        'How often do you feel that there are people you can turn to?',
#        'Suppose that you needed someone to take care of you if you were sick or injured. How often would this type of support or help be available to you?',
# ...

# %%
gasoline = pd.read_csv("http://open.africa/dataset/06088746-ecf4-46ce-9519-fec313a6ca93/resource/0f516487-6b69-48c7-bf23-f4396179a8c8/download/mama-na-mwana-system-statistics.csv")
gasoline.head()
# Out:
#                                             Category Quantity
# 0                         Mama na Mwana users (2022)   19,499
# 1                Mama na Mwana users (November 2023)   97,261
# 2                         Female Mama na Mwana users   94,255
# 3                           Male Mama na Mwana users    3,006
# 4  Regions where Mama na Mwana is running (mainla...       10

# %%
gasoline.shape
# Out:
# (531, 7)
